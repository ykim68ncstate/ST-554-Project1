# %% [markdown]
# <a href="https://colab.research.google.com/github/ykim68ncstate/ST-554-Project1/blob/t2-dev/Task2/Highlight_missing_values_on_lineplot_over_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
target_col = "C6H6(GT)"
sensor_cols = ["PT08.S1(CO)", "PT08.S2(NMHC)", "PT08.S3(NOx)",
               "PT08.S4(NO2)", "PT08.S5(O3)"]
weather_cols = ["T", "RH", "AH"]

plot_vars = [target_col]
plot_vars.extend(sensor_cols)


lineplt_df = benzene_analysis_df[plot_vars]
lineplt_df.plot(subplots=True, figsize=(20,20),layout=(6, 1), sharex=True)
plt.suptitle('Time Series of Benzene and Ground Truth Sensors (March2004 - March2005) - All Data')
plt.tight_layout()
plt.show()
